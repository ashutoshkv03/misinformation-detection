# %%
import pandas as pd

df = pd.read_csv("../data/raw/pheme_dataset.csv")
df.head()
# Out:
#                                                 text  is_rumor    user.handle  \
# 0  Charlie Hebdo became well known for publishing...       0.0     BBCDanielS
# 1  Now 10 dead in a shooting there today RT "@BBC...       0.0      robbylevy
# 2  @BBCDanielS @BBCWorld I'm guessing this is bei...       0.0  ModerateInAll
# 3  @BBCDanielS @BBCWorld why would you mention th...       0.0    GabTarquini
# 4            @BBCDanielS @BBCWorld perps identified?       0.0  freethought41
#
#           topic
# 0  charliehebdo
# 1  charliehebdo
# 2  charliehebdo
# 3  charliehebdo
# 4  charliehebdo

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 62445 entries, 0 to 62444
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   text         62445 non-null  str
#  1   is_rumor     62443 non-null  float64
#  2   user.handle  62443 non-null  str
#  3   topic        49668 non-null  str
# dtypes: float64(1), str(3)
# memory usage: 1.9 MB

# %%
df["is_rumor"].value_counts()
# Out:
# is_rumor
# 0.0    48619
# 1.0    13824
# Name: count, dtype: int64

# %%
df["text_length"] = df["text"].astype(str).apply(len)
df[["text", "text_length", "is_rumor"]].head()
# Out:
#                                                 text  text_length  is_rumor
# 0  Charlie Hebdo became well known for publishing...           82       0.0
# 1  Now 10 dead in a shooting there today RT "@BBC...          138       0.0
# 2  @BBCDanielS @BBCWorld I'm guessing this is bei...           93       0.0
# 3  @BBCDanielS @BBCWorld why would you mention th...           95       0.0
# 4            @BBCDanielS @BBCWorld perps identified?           39       0.0

# %%
import matplotlib.pyplot as plt

df["text_length"].hist(bins=40)
plt.title("Text Length Distribution")
plt.xlabel("Text Length")
plt.ylabel("Frequency")
plt.show()

# %%
df.groupby("topic")["is_rumor"].mean().sort_values(ascending=False)
# Out:
# topic
# ferguson        0.268004
# charliehebdo    0.000000
# Name: is_rumor, dtype: float64
